# %%
# !cp -r /content/drive/MyDrive/Lenguaje/Proyecto/Modules Modules
# !pip install top2vec

# %%
from sklearn.datasets import fetch_20newsgroups
from Modules.params import get_params
from top2vec import Top2Vec
from os.path import join

# %%
newsgroups = fetch_20newsgroups(subset='all',
                                remove=('headers',
                                        'footers',
                                        'quotes'))

# %%
params=get_params()
filename=join(params["path models"],
              params["news model"])
model = Top2Vec(documents=newsgroups.data, 
                speed="learn",
                embedding_model="doc2vec",
                workers=8)
model.save(filename)
# Out:
# 2022-05-18 05:35:58,368 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# 2022-05-18 05:36:06,551 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2022-05-18 05:46:47,466 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2022-05-18 05:47:08,161 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2022-05-18 05:47:10,463 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics
