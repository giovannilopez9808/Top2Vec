# %%
# !cp -r /content/drive/MyDrive/Lenguaje/Proyecto/Modules Modules
# !pip install top2vec
# Out:
# ...
#      |████████████████████████████████| 24.1 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 88 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 33.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 1.1 MB 33.3 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2342115 sha256=d6c817b5ef71e67ac0eeb6c1f348d80fbf7161c1b802a28969aa4d96d2ab68c7
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=fc79ced697c1c30832f238d01e32206dd1a57559790071a232b4b90693d8982c
#   Stored in directory: /root/.cache/pip/wheels/b3/52/a5/1fd9e3e76a7ab34f134c07469cd6f16e27ef3a37aeff1fe821
# ...

# %%
from Modules.params import get_params
from top2vec import Top2Vec
from os.path import join

# %%
params = get_params()
filename = join(params["path models"],
                params["yahoo model"])
model = Top2Vec.load(filename)

# %%
topic_words, word_scores, topic_scores, topic_nums = model.search_topics(keywords=["bush"], 
                                                                         num_topics=5)
for topic in topic_nums:
    model.generate_topic_wordcloud(topic)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model.topic_words[48]
# Out:
# array(['database', 'php', 'pages', 'page', 'access', 'server', 'code',
#        'web', 'search', 'website', 'browser', 'application', 'java',
#        'user', 'net', 'site', 'connect', 'information', 'data', 'text',
#        'results', 'address', 'create', 'google', 'interface',
#        'programming', 'connection', 'asp', 'sites', 'client', 'basic',
#        'easier', 'websites', 'write', 'links', 'using', 'engines',
#        'yahoo', 'http', 'file', 'software', 'need', 'read', 'example',
#        'useful', 'use', 'program', 'function', 'windows', 'tools'],
#       dtype='<U13')

# %%
documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=48, 
                                                                           num_docs=5)
for doc, score, doc_id in zip(documents, document_scores, document_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    print("-----------")
    print()
# Out:
# Document: 5292, Score: 0.9093338847160339
# -----------
# database administration coaching in hyderabad?  8-3-960/9 Sri Nagar Colony,Hyderabad-560073\nPhone: 0091-40-55987234
# -----------
#
# Document: 3769, Score: 0.8410372138023376
# -----------
# how do i set up a database using microsoft word?  You can set up a database with word, but how depends on what kind of database you are making. You will need another program like Access, SQL Server, PHP, etc., to call the database and retrieve the info in a useful manner. It is easier to use databse program like Access or SQL to input the data, but you can simply write the database using commas and semicolons depending on what form of simple database you are creating.
# -----------
#
# Document: 1943, Score: 0.8260202407836914
# -----------
# ...

# %%
documents, document_scores, document_ids = model.search_documents_by_keywords(keywords=["president", 
                                                                                        "internet"],
                                                                               num_docs=5)
for doc, score, doc_id in zip(documents, document_scores, document_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    print("-----------")
    print()
# Out:
# Document: 6087, Score: 0.5088313817977905
# -----------
# Afghanistan President?  Chief of State: President of the TISA, Hamid KARZAI (since 10 June 2002)\nhead of government: President of the TISA, Hamid KARZAI (since 10 June 2002)
# -----------
#
# Document: 5660, Score: 0.4929025173187256
# -----------
# Who will run for president in 2008?  Hillary Clinton.
# -----------
#
# Document: 838, Score: 0.46242374181747437
# -----------
# Is Hillary going to run for president in 2008?  Hillary Duff,  I hope so.
# -----------
#
# Document: 1934, Score: 0.4616560637950897
# -----------
# Who is the 16th president?  Abraham Lincoln.
# -----------
#
# Document: 8931, Score: 0.4486622214317322
# -----------
# Who is the DNI?  Actually, DNI stands for Director of National Intelligence, a cabinet-level position in charge of all intelligence gathering agencies. The DNI is currently John Negroponte, former ambassador to Iraq.
# -----------

# %%
words, word_scores = model.similar_words(keywords=["space"],
                                         keywords_neg=[], 
                                         num_words=20)
for word, score in zip(words, word_scores):
    print(f"{word} {score}")
# Out:
# quantum 0.3985836287441031
# universe 0.3954527986385066
# travel 0.36615751337438884
# gravity 0.35851695493938185
# smaller 0.3555049512234808
# time 0.331395540303288
# earth 0.3302676845584917
# physics 0.324155854574112
# due 0.31636813566877875
# zero 0.316081696643582
# into 0.31458133728026894
# beyond 0.3110889911431279
# disk 0.30938190321923387
# would 0.30852413389911876
# force 0.3040812602883538
# energy 0.29548287578278937
# kind 0.29517999739449763
# speed 0.290889883535303
# such 0.28940343924162953
# molecules 0.2871608568725931
